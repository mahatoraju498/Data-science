# %%
import numpy as np
total_no_of_outcomes = np.array(["head","tail"])
length = len(total_no_of_outcomes)

# %%
outcomes =[total_no_of_outcomes[np.random.randint(0,length)]for i in range(100)]

# %%
import pandas as pd
pd.Series(outcomes).value_counts()
# Out:
# head    50
# tail    50
# dtype: int64
