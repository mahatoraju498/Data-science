# %%
import pandas as pd

# %%
df = pd.read_csv("/content/tips.csv")

# %%
df.head () #previewa first 5 rows of a DataFrame
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail(3)#preview last 3 rows of a DataFrame:by defult 5 ota garxa but we can change that
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.sample(5)#randomly samples 5 rows
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3
# 104       20.92  4.08  Female     No  Sat  Dinner     2
# 38        18.69  2.31    Male     No  Sat  Dinner     3
# 105       15.36  1.64    Male    Yes  Sat  Dinner     2

# %%
 # yo sample harek patak run garda naya aauxa , same banuna seed chaincxa
 #pandas ra scikit learn ma seed lai random_state vanxa

# %%
df.sample(5,random_state =2024)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 238       35.83   4.67  Female     No   Sat  Dinner     3
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 134       18.26   3.25  Female     No  Thur   Lunch     2

# %%
df.shape#(no_of_rows, no of_columns)
# Out:
# (244, 7)

# %% [markdown]
# #Data Profiling and inspction

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df.describe()#describes the numerical data
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# 25% = Q1,
#50% = Q2/median,
#75% = Q3

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.describe (include = "object")
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %% [markdown]
# #sex column:
# - 244 rows
# - 2 unique catagories
# - among 2 unique catagories most occuring is male
# - with frequency 157

# %%
df.sex.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df.time.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
df.isna() #checks if the data contain missing data
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
#I want to count no of missing values in each column

# %%
True + True
# Out:
# 2

# %%
False + False
# Out:
# 0

# %%
False + True
# Out:
# 1

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# No missing data

# %% [markdown]
# #loc vs iloc

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #slice data in male in sex colunm

# %%
df["sex"] == "male"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: sex, Length: 244, dtype: bool

# %%
df.loc[df["sex"] == "male"]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
df['sex'] == 'female'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: sex, Length: 244, dtype: bool

# %%
df.loc[df['sex']=='female']
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %% [markdown]
# # who gives more tips on average Male or female ?

# %%
df.loc[df['sex'] == 'Male']
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
df.loc[df['sex'] == 'Male']['tip']
# Out:
# 1      1.66
# 2      3.50
# 3      3.31
# 5      4.71
# 6      2.00
#        ...
# 236    1.00
# 237    1.17
# 239    5.92
# 241    2.00
# 242    1.75
# Name: tip, Length: 157, dtype: float64

# %%
df.loc[df['sex'] == 'Male']['tip'].mean()
# Out:
# 3.0896178343949043

# %%
df.loc[df['sex'] == 'Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
df.loc[df['sex'] == 'Female']['tip']
# Out:
# 0      1.01
# 4      3.61
# 11     5.00
# 14     3.02
# 16     1.67
#        ...
# 226    2.00
# 229    2.88
# 238    4.67
# 240    2.00
# 243    3.00
# Name: tip, Length: 87, dtype: float64

# %%
df.loc[df['sex'] == 'Female']['tip'].mean()
# Out:
# 2.8334482758620685

# %%
df.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
#kun bar on average kati tip hunxa: sab vanda badi tip kun bar dinxa?

# %%
df.loc[df['day'] =='Sun'].tip.mean()
# Out:
# 3.2551315789473687

# %%
df.loc[df['day'] =='Sat'].tip.mean()
# Out:
# 2.993103448275862

# %%
#yo ta each catogries lai garnu paryo; if catogries are many it is difficult to do this

# %%
# yesko solution chai groupby

# %% [markdown]
# #Groupby

# %%
df.groupby(['day'])

# %%
df.groupby(['day'])['tip'].mean()
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
df.groupby(['day']).tip.mean()
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
df.groupby(['sex','smoker']).tip.mean()
# Out:
# sex     smoker
# Female  No        2.773519
#         Yes       2.931515
# Male    No        3.113402
#         Yes       3.051167
# Name: tip, dtype: float64

# %%
#column slice garna baki xa

# %% [markdown]
# #Loc vs iloc

# %%
#loc
#i want rows 14,15,16, and all column

# %%
df.loc[14:16,  :]
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %%
#loc use garda row slice garda last ko index linxa eg: 14:16 means 14 ,15. 16 rows ho

# %%
# row 14 -16 and column tip , sex

# %%
df.loc[14:16,['tip','sex']]
# Out:
#      tip     sex
# 14  3.02  Female
# 15  3.92    Male
# 16  1.67  Female

# %%
#kasailai tip ra sex column ta index 1 and 2 ma xa why not to use index instead of column name

# %%
df.loc[14:16, 1:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-8afe7e20a031> in <cell line: 1>()
# ----> 1 df.loc[14:16, 1:2]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
# ...

# %%
# loc  le column name matra accept garxa ; column ko index accept gardaina

# %%
# yedi column ko index dine ho vanne iloc use garnu parxa

# %%
df.iloc[14:16, 1:3]
# Out:
#      tip     sex
# 14  3.02  Female
# 15  3.92    Male

# %%
#iloc le row ra column both slice garda last ko index lidaina

# %%
# iloc ma column ko index diney ho name dina paudaina

# %% [markdown]
# #slicing DataFrame

# %%
# i want sabai rows tip and total_bill column

# %%
df[['tip','total_bill']]
# Out:
#       tip  total_bill
# 0    1.01       16.99
# 1    1.66       10.34
# 2    3.50       21.01
# 3    3.31       23.68
# 4    3.61       24.59
# ..    ...         ...
# 239  5.92       29.03
# 240  2.00       27.18
# 241  2.00       22.67
# 242  1.75       17.82
# 243  3.00       18.78
#
# [244 rows x 2 columns]

# %%
df.loc[:,['tip','total_bill']]
# Out:
#       tip  total_bill
# 0    1.01       16.99
# 1    1.66       10.34
# 2    3.50       21.01
# 3    3.31       23.68
# 4    3.61       24.59
# ..    ...         ...
# 239  5.92       29.03
# 240  2.00       27.18
# 241  2.00       22.67
# 242  1.75       17.82
# 243  3.00       18.78
#
# [244 rows x 2 columns]
