# %% [markdown]
# #Dictionary

# %%
import pandas as pd

# %%
data = {
    "country":["Nepal","India","China","Japan","USA","France"],
    "capital":["ktm","Delhi","Beijing","Tokyo","Washington DC","Paris"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   country        capital
# 0   Nepal            ktm
# 1   India          Delhi
# 2   China        Beijing
# 3   Japan          Tokyo
# 4     USA  Washington DC
# 5  France          Paris

# %%
#other Method

# %%
data = {
    "country":["Nepal","India","China","Japan","USA","France"],
    "capital":["ktm","Delhi","Beijing","Tokyo","Washington DC","Paris"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   country        capital
# 0   Nepal            ktm
# 1   India          Delhi
# 2   China        Beijing
# 3   Japan          Tokyo
# 4     USA  Washington DC
# 5  France          Paris

# %%
df.rename({"capital":"capital city"},axis = "columns", inplace = True) #update the df variable
df
# Out:
#   country   capital city
# 0   Nepal            ktm
# 1   India          Delhi
# 2   China        Beijing
# 3   Japan          Tokyo
# 4     USA  Washington DC
# 5  France          Paris

# %% [markdown]
# #How to access columns in DataFrame

# %%
data = {
    "country":["Nepal","India","China","Japan","USA","France"],
    "capital":["ktm","Delhi","Beijing","Tokyo","Washington DC","Paris"]
}
df = pd.DataFrame(data)
df
# Out:
#   country        capital
# 0   Nepal            ktm
# 1   India          Delhi
# 2   China        Beijing
# 3   Japan          Tokyo
# 4     USA  Washington DC
# 5  France          Paris

# %%
df["country"]
# Out:
# 0     Nepal
# 1     India
# 2     China
# 3     Japan
# 4       USA
# 5    France
# Name: country, dtype: object

# %%
df["capital"]
# Out:
# 0              ktm
# 1            Delhi
# 2          Beijing
# 3            Tokyo
# 4    Washington DC
# 5            Paris
# Name: capital, dtype: object

# %%
df.country
# Out:
# 0     Nepal
# 1     India
# 2     China
# 3     Japan
# 4       USA
# 5    France
# Name: country, dtype: object

# %%
df.capital
# Out:
# 0              ktm
# 1            Delhi
# 2          Beijing
# 3            Tokyo
# 4    Washington DC
# 5            Paris
# Name: capital, dtype: object

# %%
dfs = pd.DataFrame({'c1': ['v1','v2'], 'col 2': ['v22','v23']})
dfs
# Out:
#    c1 col 2
# 0  v1   v22
# 1  v2   v23

# %%
dfs['col 2']
# Out:
# 0    v22
# 1    v23
# Name: col 2, dtype: object

# %%
dfs.col 2
# Out:
#   File "<ipython-input-24-2ff05e7fcc6e>", line 1
#     dfs.col 2
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Deleting a column in DataFrame

# %%
dfs = pd.DataFrame({'c1': ['v1','v2'], 'col 2': ['v22','v23']})
dfs
# Out:
#    c1 col 2
# 0  v1   v22
# 1  v2   v23

# %%
del dfs["col 2"]
dfs
# Out:
#    c1
# 0  v1
# 1  v2

# %%
dfs = pd.DataFrame({'c1': ['v1','v2'], 'col 2': ['v22','v23']})
#other ways

# %%
dfs.drop(columns = ['col 2'],inplace = True)
dfs
# Out:
#    c1
# 0  v1
# 1  v2

# %% [markdown]
# #Adding a new colunm a DataFrame

# %%
df = pd.DataFrame({"name":["champa","radhe","govinda"]})

# %%
df
# Out:
#       name
# 0   champa
# 1    radhe
# 2  govinda

# %%
df["gender"] = ['female',"female","male"] #adds a new column called gender which has value

# %%
df['age'] = [25,27,21]

# %%
df['address'] = ["ktm", "bkt","bkt"]
df   #df.column_name = [] garera value assign garna paudaina
# Out:
#       name  gender  age address
# 0   champa  female   25     ktm
# 1    radhe  female   27     bkt
# 2  govinda    male   21     bkt
