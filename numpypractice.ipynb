# %%
import numpy as np

# %%
 x = np.array([])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([], dtype=float64)

# %%
even = [2,4,6,8,10]

# %%
even_array = np.array(even)

# %%
even_array
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
type(even_array)
# Out:
# numpy.ndarray

# %%
#nd means n dimensional array

# %%
even_array.ndim ## gives the dimensional of array
# Out:
# 1

# %%
even_array.shape #length of array
# Out:
# (5,)

# %%
len(even_array)
# Out:
# 5

# %% [markdown]
# #indexing and slicing

# %%
x = np.array([3,4,5,6,7,8])

# %%
x[3]
# Out:
# 6

# %%
x[-2]
# Out:
# 7

# %%
x[4:]
# Out:
# array([7, 8])

# %%
x[:5]
# Out:
# array([3, 4, 5, 6, 7])

# %%
x[-2:-4]
# Out:
# array([], dtype=int64)

# %%
x[-4:-2]
# Out:
# array([5, 6])

# %% [markdown]
# #Differnet between list and array
# *Array operation are faster than the list that means array is faster than list .
