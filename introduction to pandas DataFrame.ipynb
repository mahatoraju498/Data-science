# %%
import pandas as pd

# %%
s1 = pd.Series(["Simran","Rohit","Amisha"],name = "name")
s2 = pd.Series(["F", "M", "F"], name = "gender")

# %%
df = pd.concat([s1,s2], axis = "columns")

# %%
df
# Out:
#      name gender
# 0  Simran      F
# 1   Rohit      M
# 2  Amisha      F

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #Crating a DataFrame using list of list

# %%
data = [["e01","kshitiz"],["e02","shyam"],["e03","Rita"]]
df = pd.DataFrame(data)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
#how to add colomn name?

# %%
data = [["e01","kshitiz"],["e02","shyam"],["e03","Rita"]]
df = pd.DataFrame(data, columns = ['emp_id','emp_name'])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
data = [["e01","kshitiz"],["e02","shyam"],["e03","Rita"]]
df = pd.DataFrame(data)
df.columns = ['emp_id','emp_name']
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
# ...
